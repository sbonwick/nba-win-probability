# %%
import src.utils.io as io
import src.data.cache as cache
import src.features.game_state as gs
import pandas as pd

game_id = "0042500311"
year = "2025-26"
season_type = "Playoffs"

test = gs.prepare_tables(game_id, season_type, year)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows",None)
pd.set_option("display.max_colwidth", None)

test

# %%
import src.utils.io as io
import src.data.cache as cache
import src.features.game_state as gs
import pandas as pd

game_id = "0021500440"
year = "2015-16"
season_type = "Regular Season"

test = gs.prepare_tables(game_id, season_type, year)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows",None)
pd.set_option("display.max_colwidth", None)

test

# %%
import src.utils.io as io
import src.data.cache as cache
import src.features.game_state as gs
import pandas as pd

game_id = "0041500403"
year = "2015-16"
season_type = "Playoffs"

test = gs.prepare_tables(game_id, season_type, year)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows",None)
pd.set_option("display.max_colwidth", None)

test

# %%
import src.utils.io as io
import src.data.cache as cache
import src.features.game_state as gs
import pandas as pd

game_id = "0042000217"
year = "2020-21"
season_type = "Playoffs"

test = gs.prepare_tables(game_id, season_type, year)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows",None)
pd.set_option("display.max_colwidth", None)

test

# %%
import src.utils.io as io
import src.data.cache as cache
import src.features.game_state as gs
import pandas as pd

game_id = "0022300552"
year = "2023-24"
season_type = "Regular Season"

test = gs.prepare_tables(game_id, season_type, year)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows",None)
pd.set_option("display.max_colwidth", None)

test
# Out:
#      period  scoreHome  scoreAway  home_wins  home_losses  home_won  \
# 0         1          0          0         28           12      True
# 1         1          0          0         28           12      True
# 2         1          0          0         28           12      True
# 3         1          0          0         28           12      True
# 4         1          0          0         28           12      True
# 5         1          0          2         28           12      True
# 6         1          2          2         28           12      True
# 7         1          2          2         28           12      True
# 8         1          2          2         28           12      True
# 9         1          2          2         28           12      True
# 10        1          2          2         28           12      True
# 11        1          4          2         28           12      True
# 12        1          4          2         28           12      True
# ...
